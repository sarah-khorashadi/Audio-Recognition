# %%
# !pip install AudioSegment
# !pip install scipy
# !pip install audiomentations

# %%
# !rm -r 12words/
# !rm -r 12words_trimmed/

# %% [markdown]
# ## Importing Essential Libraries

# %%
import os
import pathlib
import glob
import itertools
import librosa
import scipy.io.wavfile

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import models
from IPython import display


from pydub import AudioSegment
from audiomentations import Compose, AddGaussianNoise, TimeStretch, PitchShift, Shift

# %% [markdown]
# ## Retrieving and Unpacking the Dataset

# %%
# download dataset zip file from google drive
# !gdown 1SwbFteTP21-F6T5f32zF8hvRX1cE0h8c
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1SwbFteTP21-F6T5f32zF8hvRX1cE0h8c
# From (redirected): https://drive.google.com/uc?id=1SwbFteTP21-F6T5f32zF8hvRX1cE0h8c&confirm=t&uuid=8205b04f-f2c5-4f31-a353-612ff3b1ce5c
# To: /content/12words.zip
# 100% 35.1M/35.1M [00:00<00:00, 63.3MB/s]

# %%
# Unzip dataset
# !unzip -qq -d 12words/ 12words.zip

# %% [markdown]
# ## Detecting and Trimming Silence in Audio Data

# %%
DATASET_PATH = '/content/12words/'
data_dir = pathlib.Path(DATASET_PATH)

# %%
classes = np.array(tf.io.gfile.listdir(str(data_dir)))
print('Classes:', classes)
# Out:
# Classes: ['15' '1' '5' '4' '19' '7' '3' '9' '13' '8' '11' '17']

# %%
# https://github.com/jiaaro/pydub/tree/0c26b10619ee6e31c2b0ae26a8e99f461f694e5f

def db_to_float(db, using_amplitude=True):
    """
    Converts the input db to a float, which represents the equivalent
    ratio in power.
    """
    db = float(db)
    if using_amplitude:
        return 10 ** (db / 20)
    else:  # using power
        return 10 ** (db / 10)

def detect_silence(audio_segment, min_silence_len, silence_thresh, seek_step):
    """
    Returns a list of all silent sections [start, end] in milliseconds of audio_segment.
    Inverse of detect_nonsilent()

    audio_segment - the segment to find silence in
    min_silence_len - the minimum length for any silent section
    silence_thresh - the upper bound for how quiet is silent in dFBS
    seek_step - step size for interating over the segment in ms
    """
    seg_len = len(audio_segment)

    # you can't have a silent portion of a sound that is longer than the sound
    if seg_len < min_silence_len:
        return []

    # convert silence threshold to a float value (so we can compare it to rms)
    silence_thresh = db_to_float(silence_thresh) * audio_segment.max_possible_amplitude

    # find silence and add start and end indicies to the to_cut list
    silence_starts = []

    # check successive (1 sec by default) chunk of sound for silence
    # try a chunk at every "seek step" (or every chunk for a seek step == 1)
    last_slice_start = seg_len - min_silence_len
    slice_starts = range(0, last_slice_start + 1, seek_step)

    # guarantee last_slice_start is included in the range
    # to make sure the last portion of the audio is searched
    if last_slice_start % seek_step:
        slice_starts = itertools.chain(slice_starts, [last_slice_start])

    for i in slice_starts:
        audio_slice = audio_segment[i:i + min_silence_len]
        if audio_slice.rms <= silence_thresh:
            silence_starts.append(i)

    # short circuit when there is no silence
    if not silence_starts:
        return []

    # combine the silence we detected into ranges (start ms - end ms)
    silent_ranges = []

    prev_i = silence_starts.pop(0)
    current_range_start = prev_i

    for silence_start_i in silence_starts:
        continuous = (silence_start_i == prev_i + seek_step)

        # sometimes two small blips are enough for one particular slice to be
        # non-silent, despite the silence all running together. Just combine
        # the two overlapping silent ranges.
        silence_has_gap = silence_start_i > (prev_i + min_silence_len)

        if not continuous and silence_has_gap:
            silent_ranges.append([current_range_start,
                                  prev_i + min_silence_len])
            current_range_start = silence_start_i
        prev_i = silence_start_i

    silent_ranges.append([current_range_start,
                          prev_i + min_silence_len])

    return silent_ranges

def detect_nonsilent(audio_segment, min_silence_len, silence_thresh, seek_step):
    """
    Returns a list of all nonsilent sections [start, end] in milliseconds of audio_segment.
    Inverse of detect_silent()

    audio_segment - the segment to find silence in
    min_silence_len - the minimum length for any silent section
    silence_thresh - the upper bound for how quiet is silent in dFBS
    seek_step - step size for interating over the segment in ms
    """
    silent_ranges = detect_silence(audio_segment, min_silence_len, silence_thresh, seek_step)
    len_seg = len(audio_segment)

    # if there is no silence, the whole thing is nonsilent
    if not silent_ranges:
        return [[0, len_seg]]

    # short circuit when the whole audio segment is silent
    if silent_ranges[0][0] == 0 and silent_ranges[0][1] == len_seg:
        return []

    prev_end_i = 0
    nonsilent_ranges = []
    for start_i, end_i in silent_ranges:
        nonsilent_ranges.append([prev_end_i, start_i])
        prev_end_i = end_i

    if end_i != len_seg:
        nonsilent_ranges.append([prev_end_i, len_seg])

    if nonsilent_ranges[0] == [0, 0]:
        nonsilent_ranges.pop(0)

    return nonsilent_ranges

def split_on_silence(audio_segment, min_silence_len=1000, silence_thresh=-40,
                     keep_silence=250, seek_step=1):
    """
    Returns list of audio segments from splitting audio_segment on silent sections

    audio_segment - original pydub.AudioSegment() object

    min_silence_len - (in ms) minimum length of a silence to be used for
        a split. default: 1000ms

    silence_thresh - (in dBFS) anything quieter than this will be
        considered silence. default: -16dBFS

    keep_silence - (in ms or True/False) leave some silence at the beginning
        and end of the chunks. Keeps the sound from sounding like it
        is abruptly cut off.
        When the length of the silence is less than the keep_silence duration
        it is split evenly between the preceding and following non-silent
        segments.
        If True is specified, all the silence is kept, if False none is kept.
        default: 100ms

    seek_step - step size for interating over the segment in ms
    """

    # from the itertools documentation
    def pairwise(iterable):
        "s -> (s0,s1), (s1,s2), (s2, s3), ..."
        a, b = itertools.tee(iterable)
        next(b, None)
        return zip(a, b)

    if isinstance(keep_silence, bool):
        keep_silence = len(audio_segment) if keep_silence else 0

    output_ranges = [
        [ start - keep_silence, end + keep_silence ]
        for (start,end)
            in detect_nonsilent(audio_segment, min_silence_len, silence_thresh, seek_step)
    ]

    for range_i, range_ii in pairwise(output_ranges):
        last_end = range_i[1]
        next_start = range_ii[0]
        if next_start < last_end:
            range_i[1] = (last_end+next_start)//2
            range_ii[0] = range_i[1]

    return [
        audio_segment[ max(start,0) : min(end,len(audio_segment)) ]
        for start,end in output_ranges
    ]

# %%
def trim_mp3(mp3_file, output_folder):
    audio_segment = AudioSegment.from_mp3(mp3_file)
    os.makedirs(output_folder, exist_ok=True)
    audio_segment_list = split_on_silence(audio_segment)
    for idx, extracted_audio_segment in enumerate(audio_segment_list):
        if extracted_audio_segment.duration_seconds > 0.75:
            out_fn = os.path.join(output_folder,
                                  os.path.splitext(os.path.basename(mp3_file))[0] + "_" + str(idx) + "_extracted.mp3")
            extracted_audio_segment.export(out_fn, format="mp3")

# %%
# ~ 4 min
for f in glob.glob(os.path.join(DATASET_PATH, '*/*.mp3')):
    trim_mp3(f, os.path.dirname(f))

# %% [markdown]
# ## Converting MP3 Audio Files to WAV Format

# %%
# function for converting mp3 file into wav file
def convert_mp3_to_wav(mp3_file, output_folder):
    sound = AudioSegment.from_mp3(mp3_file)
    os.makedirs(output_folder, exist_ok=True)
    wav_fn = os.path.join(output_folder, os.path.splitext(os.path.basename(mp3_file))[0] + ".wav")
    duration = sound.duration_seconds
    sound.set_frame_rate(16000).export(wav_fn, format="wav")
    return duration

# %%
durations = []

for f in glob.glob(os.path.join(DATASET_PATH, '*/*_extracted.mp3')):
  d = convert_mp3_to_wav(f, os.path.dirname(f))
  durations.append(d)

# %%
durations_np = np.array(durations)

plt.boxplot(durations_np)

plt.show()

# %%
SAMPLE_RATE = 16000
DURATION = 4

# %% [markdown]
# ## Data Augmentation Pipeline for Audio Files

# %%
augment_vo = Compose([
    AddGaussianNoise(min_amplitude=0.001, max_amplitude=0.015, p=0.5),
    TimeStretch(min_rate=0.8, max_rate=1.25, p=0.5),
    PitchShift(min_semitones=-4, max_semitones=4, p=0.5),
    Shift(p=0.5),
])

# %%
augment_vt = Compose([
    AddGaussianNoise(min_amplitude=0.005, max_amplitude=0.02, p=0.5),
    TimeStretch(min_rate=0.75, max_rate=1.5, p=0.5),
    PitchShift(min_semitones=-3, max_semitones=3, p=0.5),
    Shift(p=0.7),
])

# %%
def augment_audio(samples, sample_rate, augment_func):
    augmented_samples = augment_func(samples=samples, sample_rate=sample_rate)
    if augmented_samples.dtype != 'int16':
        augmented_samples = (augmented_samples * 32767).astype('int16')  # Convert to 16-bit PCM
    return augmented_samples

# %%
augment_functions = [augment_vt, augment_vo]
for index, augment_function in enumerate(augment_functions):
  for f in glob.glob(os.path.join(DATASET_PATH, '*/*_extracted.wav')):
      data = librosa.core.load(f)[0]
      sound_aug = augment_audio(data, SAMPLE_RATE, augment_function)
      wav_aug = os.path.join(os.path.dirname(f), os.path.splitext(os.path.basename(f))[0] +'_'+str(index)+ '_aug' + ".wav")
      scipy.io.wavfile.write(wav_aug, SAMPLE_RATE, sound_aug)

# %% [markdown]
# ## Clean Data

# %%
# !cp -r 12words/ 12words_trimmed/

# %%
# !rm 12words/*/*.mp3

# %%
# !rm 12words_trimmed/*/*\).wav
# Out:
# rm: cannot remove '12words_trimmed/*/*).wav': No such file or directory

# %%
# !rm 12words_trimmed/*/*.mp3

# %% [markdown]
# ## Audio Dataset Splitting for Training and Testing

# %%
DATASET_PATH = '/content/12words_trimmed/'
data_dir = pathlib.Path(DATASET_PATH)

# %%
train_ds, val_ds = tf.keras.utils.audio_dataset_from_directory(
    directory=data_dir,
    batch_size=64,
    validation_split=0.2,
    seed=0,
    output_sequence_length=DURATION*SAMPLE_RATE,
    subset='both')

label_names = np.array(train_ds.class_names)
print()
print("label names:", label_names)
# Out:
# Found 1404 files belonging to 12 classes.
# Using 1124 files for training.
# Using 280 files for validation.
#
# label names: ['1' '11' '13' '15' '17' '19' '3' '4' '5' '7' '8' '9']

# %%
def squeeze(audio, labels):
  audio = tf.squeeze(audio, axis=-1)
  return audio, labels

train_ds = train_ds.map(squeeze, tf.data.AUTOTUNE)
val_ds = val_ds.map(squeeze, tf.data.AUTOTUNE)

# %%
test_ds = val_ds.shard(num_shards=2, index=0)
val_ds = val_ds.shard(num_shards=2, index=1)

# %%
for example_audio, example_labels in train_ds.take(1):
    print(example_audio.shape)
    print(example_labels.shape)
# Out:
# (64, 64000)
# (64,)

# %%
plt.figure(figsize=(16, 10))
rows = 3
cols = 3
n = rows * cols
for i in range(n):
    plt.subplot(rows, cols, i+1)
    audio_signal = example_audio[i]
    plt.plot(audio_signal)
    plt.title(label_names[example_labels[i]])
    plt.yticks(np.arange(-1.2, 1.2, 0.2))
    plt.ylim([-1.1, 1.1])

# %% [markdown]
# ## Spectrogram Generation from Audio Data

# %%
def get_spectrogram(waveform):
    # Convert the waveform to a spectrogram via a STFT.
    spectrogram = tf.signal.stft(
        waveform, frame_length=255, frame_step=128)
    # Obtain the magnitude of the STFT.
    spectrogram = tf.abs(spectrogram)
    # Add a `channels` dimension, so that the spectrogram can be used
    # as image-like input data with convolution layers (which expect
    # shape (`batch_size`, `height`, `width`, `channels`).
    spectrogram = spectrogram[..., tf.newaxis]
    return spectrogram

# %%
for i in range(3):
    label = label_names[example_labels[i]]
    waveform = example_audio[i]
    spectrogram = get_spectrogram(waveform)

    print('Label:', label)
    print('Waveform shape:', waveform.shape)
    print('Spectrogram shape:', spectrogram.shape)
    print('Audio playback')
    display.display(display.Audio(waveform, rate=SAMPLE_RATE))
# Out:
# Label: 11
# Waveform shape: (64000,)
# Spectrogram shape: (499, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label: 8
# Waveform shape: (64000,)
# Spectrogram shape: (499, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Label: 5
# Waveform shape: (64000,)
# Spectrogram shape: (499, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def plot_spectrogram(spectrogram, ax):
    if len(spectrogram.shape) > 2:
      assert len(spectrogram.shape) == 3
      spectrogram = np.squeeze(spectrogram, axis=-1)
    # Convert the frequencies to log scale and transpose, so that the time is
    # represented on the x-axis (columns).
    # Add an epsilon to avoid taking a log of zero.
    log_spec = np.log(spectrogram.T + np.finfo(float).eps)
    height = log_spec.shape[0]
    width = log_spec.shape[1]
    X = np.linspace(0, np.size(spectrogram), num=width, dtype=int)
    Y = range(height)
    ax.pcolormesh(X, Y, log_spec)

# %%
fig, axes = plt.subplots(2, figsize=(12, 8))
timescale = np.arange(waveform.shape[0])
axes[0].plot(timescale, waveform.numpy())
axes[0].set_title('Waveform')
axes[0].set_xlim([0, DURATION*SAMPLE_RATE])

plot_spectrogram(spectrogram.numpy(), axes[1])
axes[1].set_title('Spectrogram')
plt.suptitle(label.title())
plt.show()

# %%
def make_spec_ds(ds):
    return ds.map(
        map_func=lambda audio,label: (get_spectrogram(audio), label),
        num_parallel_calls=tf.data.AUTOTUNE)

# %%
train_spectrogram_ds = make_spec_ds(train_ds)
val_spectrogram_ds = make_spec_ds(val_ds)
test_spectrogram_ds = make_spec_ds(test_ds)

# %%
for example_spectrograms, example_spect_labels in train_spectrogram_ds.take(1):
  break

# %%
rows = 3
cols = 3
n = rows*cols
fig, axes = plt.subplots(rows, cols, figsize=(16, 9))

for i in range(n):
    r = i // cols
    c = i % cols
    ax = axes[r][c]
    plot_spectrogram(example_spectrograms[i].numpy(), ax)
    ax.set_title(label_names[example_spect_labels[i].numpy()])

plt.show()

# %%
train_spectrogram_ds = train_spectrogram_ds.cache().shuffle(1000).prefetch(tf.data.AUTOTUNE)
val_spectrogram_ds = val_spectrogram_ds.cache().prefetch(tf.data.AUTOTUNE)
test_spectrogram_ds = test_spectrogram_ds.cache().prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ## Model Training Pipeline for Audio Classification

# %%
# Define the checkpoint file path
MODEL_PATH = '/content/'
checkpoint_path = os.path.join(MODEL_PATH, 'model_checkpoint.h5')

# %%
from keras.regularizers import l2

input_shape = example_spectrograms.shape[1:]
print('Input shape:', input_shape)
num_labels = len(label_names)
print(num_labels)
# Instantiate the `tf.keras.layers.Normalization` layer.
norm_layer = layers.Normalization()
# Fit the state of the layer to the spectrograms
# with `Normalization.adapt`.
norm_layer.adapt(data=train_spectrogram_ds.map(map_func=lambda spec, label: spec))

model = models.Sequential([
    layers.Input(shape=input_shape),
    # Downsample the input.
    layers.Resizing(64, 64),
    # Normalize.
    norm_layer,
    layers.Conv2D(16, 3, strides=2, activation=None, padding='same'),
    layers.BatchNormalization(),
    layers.ReLU(),
    layers.Conv2D(16, 3, strides=1, activation=None, padding='same'),
    layers.BatchNormalization(),
    layers.Dropout(0.25),
    layers.Conv2D(16, 3, strides=1, activation=None, padding='same'),
    layers.BatchNormalization(),
    layers.ReLU(),
    layers.Conv2D(16, 3, strides=1, activation=None, padding='same'),
    layers.BatchNormalization(),

    layers.Conv2D(32, 3, strides=2, activation=None, padding='same'),
    layers.BatchNormalization(),
    layers.ReLU(),
    layers.Conv2D(32, 3, strides=1, activation=None, padding='same'),
    layers.BatchNormalization(),
    layers.Dropout(0.25),
    layers.Conv2D(32, 3, strides=1, activation=None, padding='same'),
    layers.BatchNormalization(),
    layers.ReLU(),
    layers.Conv2D(32, 3, strides=1, activation=None, padding='same'),
    layers.BatchNormalization(),

    layers.Flatten(),
    layers.Dense(64, activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)),
    layers.Dropout(0.5),
    layers.Dense(num_labels, kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)),
])

model.summary()
# Out:
# Input shape: (499, 129, 1)
# 12
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resizing (Resizing)         (None, 64, 64, 1)         0
#
#  normalization (Normalizati  (None, 64, 64, 1)         3
#  on)
#
#  conv2d (Conv2D)             (None, 32, 32, 16)        160
#
#  batch_normalization (Batch  (None, 32, 32, 16)        64
#  Normalization)
#
#  re_lu (ReLU)                (None, 32, 32, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 16)        2320
#
#  batch_normalization_1 (Bat  (None, 32, 32, 16)        64
#  chNormalization)
#
#  dropout (Dropout)           (None, 32, 32, 16)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 16)        2320
#
#  batch_normalization_2 (Bat  (None, 32, 32, 16)        64
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 32, 32, 16)        0
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 16)        2320
#
#  batch_normalization_3 (Bat  (None, 32, 32, 16)        64
#  chNormalization)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 32)        4640
#
#  batch_normalization_4 (Bat  (None, 16, 16, 32)        128
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 16, 16, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 32)        9248
#
#  batch_normalization_5 (Bat  (None, 16, 16, 32)        128
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 32)        9248
#
#  batch_normalization_6 (Bat  (None, 16, 16, 32)        128
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 16, 16, 32)        0
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 32)        9248
#
#  batch_normalization_7 (Bat  (None, 16, 16, 32)        128
#  chNormalization)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 64)                524352
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 12)                780
#
# =================================================================
# Total params: 565407 (2.16 MB)
# Trainable params: 565020 (2.16 MB)
# Non-trainable params: 387 (1.52 KB)
# _________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %%
EPOCHS = 100
history = model.fit(
    train_spectrogram_ds,
    validation_data=val_spectrogram_ds,
    epochs=EPOCHS,
    callbacks=[tf.keras.callbacks.EarlyStopping(verbose=1, patience=15),
               tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=False,
    save_best_only=True,
    monitor='val_accuracy',
    mode='max',
    verbose=1
)]
)
# Out:
# Epoch 1/100
# 18/18 [==============================] - ETA: 0s - loss: 4.1898 - accuracy: 0.0952
# Epoch 1: val_accuracy improved from -inf to 0.10156, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 13s 473ms/step - loss: 4.1898 - accuracy: 0.0952 - val_loss: 3.8124 - val_accuracy: 0.1016
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2/100
# 18/18 [==============================] - ETA: 0s - loss: 3.6886 - accuracy: 0.0943
# Epoch 2: val_accuracy improved from 0.10156 to 0.11719, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 7s 402ms/step - loss: 3.6886 - accuracy: 0.0943 - val_loss: 3.5601 - val_accuracy: 0.1172
# Epoch 3/100
# 18/18 [==============================] - ETA: 0s - loss: 3.4387 - accuracy: 0.0907
# Epoch 3: val_accuracy did not improve from 0.11719
# 18/18 [==============================] - 6s 326ms/step - loss: 3.4387 - accuracy: 0.0907 - val_loss: 3.3329 - val_accuracy: 0.1094
# Epoch 4/100
# 18/18 [==============================] - ETA: 0s - loss: 3.2291 - accuracy: 0.0934
# Epoch 4: val_accuracy did not improve from 0.11719
# 18/18 [==============================] - 7s 403ms/step - loss: 3.2291 - accuracy: 0.0934 - val_loss: 3.1677 - val_accuracy: 0.0781
# Epoch 5/100
# 18/18 [==============================] - ETA: 0s - loss: 3.0848 - accuracy: 0.0854
# Epoch 5: val_accuracy did not improve from 0.11719
# 18/18 [==============================] - 7s 411ms/step - loss: 3.0848 - accuracy: 0.0854 - val_loss: 3.0579 - val_accuracy: 0.0625
# Epoch 6/100
# 18/18 [==============================] - ETA: 0s - loss: 3.0002 - accuracy: 0.1014
# Epoch 6: val_accuracy did not improve from 0.11719
# 18/18 [==============================] - 6s 339ms/step - loss: 3.0002 - accuracy: 0.1014 - val_loss: 2.9681 - val_accuracy: 0.0859
# Epoch 7/100
# 18/18 [==============================] - ETA: 0s - loss: 2.9040 - accuracy: 0.1050
# Epoch 7: val_accuracy did not improve from 0.11719
# 18/18 [==============================] - 6s 338ms/step - loss: 2.9040 - accuracy: 0.1050 - val_loss: 2.8736 - val_accuracy: 0.1094
# Epoch 8/100
# 18/18 [==============================] - ETA: 0s - loss: 2.8206 - accuracy: 0.1183
# Epoch 8: val_accuracy improved from 0.11719 to 0.13281, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 7s 381ms/step - loss: 2.8206 - accuracy: 0.1183 - val_loss: 2.8172 - val_accuracy: 0.1328
# Epoch 9/100
# 18/18 [==============================] - ETA: 0s - loss: 2.7792 - accuracy: 0.1352
# Epoch 9: val_accuracy did not improve from 0.13281
# 18/18 [==============================] - 7s 366ms/step - loss: 2.7792 - accuracy: 0.1352 - val_loss: 2.7927 - val_accuracy: 0.0781
# Epoch 10/100
# 18/18 [==============================] - ETA: 0s - loss: 2.6787 - accuracy: 0.1504
# Epoch 10: val_accuracy did not improve from 0.13281
# 18/18 [==============================] - 6s 339ms/step - loss: 2.6787 - accuracy: 0.1504 - val_loss: 2.6752 - val_accuracy: 0.1094
# Epoch 11/100
# 18/18 [==============================] - ETA: 0s - loss: 2.6322 - accuracy: 0.1904
# Epoch 11: val_accuracy did not improve from 0.13281
# 18/18 [==============================] - 6s 342ms/step - loss: 2.6322 - accuracy: 0.1904 - val_loss: 2.6436 - val_accuracy: 0.1250
# Epoch 12/100
# 18/18 [==============================] - ETA: 0s - loss: 2.5665 - accuracy: 0.1868
# Epoch 12: val_accuracy improved from 0.13281 to 0.21875, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 7s 420ms/step - loss: 2.5665 - accuracy: 0.1868 - val_loss: 2.5318 - val_accuracy: 0.2188
# Epoch 13/100
# 18/18 [==============================] - ETA: 0s - loss: 2.4484 - accuracy: 0.2438
# Epoch 13: val_accuracy improved from 0.21875 to 0.27344, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 6s 349ms/step - loss: 2.4484 - accuracy: 0.2438 - val_loss: 2.4194 - val_accuracy: 0.2734
# Epoch 14/100
# 18/18 [==============================] - ETA: 0s - loss: 2.3565 - accuracy: 0.2847
# Epoch 14: val_accuracy improved from 0.27344 to 0.29688, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 6s 334ms/step - loss: 2.3565 - accuracy: 0.2847 - val_loss: 2.2979 - val_accuracy: 0.2969
# Epoch 15/100
# 18/18 [==============================] - ETA: 0s - loss: 2.3272 - accuracy: 0.2909
# Epoch 15: val_accuracy improved from 0.29688 to 0.35938, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 9s 503ms/step - loss: 2.3272 - accuracy: 0.2909 - val_loss: 2.2510 - val_accuracy: 0.3594
# Epoch 16/100
# 18/18 [==============================] - ETA: 0s - loss: 2.2942 - accuracy: 0.2900
# Epoch 16: val_accuracy improved from 0.35938 to 0.45312, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 6s 345ms/step - loss: 2.2942 - accuracy: 0.2900 - val_loss: 2.1524 - val_accuracy: 0.4531
# Epoch 17/100
# 18/18 [==============================] - ETA: 0s - loss: 2.1056 - accuracy: 0.3577
# Epoch 17: val_accuracy did not improve from 0.45312
# 18/18 [==============================] - 7s 406ms/step - loss: 2.1056 - accuracy: 0.3577 - val_loss: 1.9886 - val_accuracy: 0.4453
# Epoch 18/100
# 18/18 [==============================] - ETA: 0s - loss: 1.9750 - accuracy: 0.4368
# Epoch 18: val_accuracy improved from 0.45312 to 0.46875, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 6s 340ms/step - loss: 1.9750 - accuracy: 0.4368 - val_loss: 1.9461 - val_accuracy: 0.4688
# Epoch 19/100
# 18/18 [==============================] - ETA: 0s - loss: 1.8976 - accuracy: 0.4404
# Epoch 19: val_accuracy improved from 0.46875 to 0.49219, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 6s 347ms/step - loss: 1.8976 - accuracy: 0.4404 - val_loss: 1.9070 - val_accuracy: 0.4922
# Epoch 20/100
# 18/18 [==============================] - ETA: 0s - loss: 1.8304 - accuracy: 0.4938
# Epoch 20: val_accuracy improved from 0.49219 to 0.53125, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 6s 343ms/step - loss: 1.8304 - accuracy: 0.4938 - val_loss: 1.8509 - val_accuracy: 0.5312
# Epoch 21/100
# 18/18 [==============================] - ETA: 0s - loss: 1.7462 - accuracy: 0.5418
# Epoch 21: val_accuracy improved from 0.53125 to 0.59375, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 6s 335ms/step - loss: 1.7462 - accuracy: 0.5418 - val_loss: 1.7061 - val_accuracy: 0.5938
# Epoch 22/100
# 18/18 [==============================] - ETA: 0s - loss: 1.6432 - accuracy: 0.5578
# Epoch 22: val_accuracy improved from 0.59375 to 0.60938, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 7s 424ms/step - loss: 1.6432 - accuracy: 0.5578 - val_loss: 1.7290 - val_accuracy: 0.6094
# Epoch 23/100
# 18/18 [==============================] - ETA: 0s - loss: 1.5917 - accuracy: 0.6228
# Epoch 23: val_accuracy did not improve from 0.60938
# 18/18 [==============================] - 6s 328ms/step - loss: 1.5917 - accuracy: 0.6228 - val_loss: 1.8006 - val_accuracy: 0.5469
# Epoch 24/100
# 18/18 [==============================] - ETA: 0s - loss: 1.5924 - accuracy: 0.6130
# Epoch 24: val_accuracy did not improve from 0.60938
# 18/18 [==============================] - 6s 337ms/step - loss: 1.5924 - accuracy: 0.6130 - val_loss: 1.7834 - val_accuracy: 0.5703
# Epoch 25/100
# 18/18 [==============================] - ETA: 0s - loss: 1.5332 - accuracy: 0.6370
# Epoch 25: val_accuracy did not improve from 0.60938
# 18/18 [==============================] - 6s 336ms/step - loss: 1.5332 - accuracy: 0.6370 - val_loss: 1.9149 - val_accuracy: 0.4922
# Epoch 26/100
# 18/18 [==============================] - ETA: 0s - loss: 1.4721 - accuracy: 0.6824
# Epoch 26: val_accuracy did not improve from 0.60938
# 18/18 [==============================] - 7s 404ms/step - loss: 1.4721 - accuracy: 0.6824 - val_loss: 1.6744 - val_accuracy: 0.6094
# Epoch 27/100
# 18/18 [==============================] - ETA: 0s - loss: 1.4127 - accuracy: 0.7073
# Epoch 27: val_accuracy improved from 0.60938 to 0.68750, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 9s 477ms/step - loss: 1.4127 - accuracy: 0.7073 - val_loss: 1.5097 - val_accuracy: 0.6875
# Epoch 28/100
# 18/18 [==============================] - ETA: 0s - loss: 1.3480 - accuracy: 0.7233
# Epoch 28: val_accuracy did not improve from 0.68750
# 18/18 [==============================] - 6s 334ms/step - loss: 1.3480 - accuracy: 0.7233 - val_loss: 1.5083 - val_accuracy: 0.6797
# Epoch 29/100
# 18/18 [==============================] - ETA: 0s - loss: 1.3276 - accuracy: 0.7180
# Epoch 29: val_accuracy improved from 0.68750 to 0.73438, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 7s 407ms/step - loss: 1.3276 - accuracy: 0.7180 - val_loss: 1.3809 - val_accuracy: 0.7344
# Epoch 30/100
# 18/18 [==============================] - ETA: 0s - loss: 1.3114 - accuracy: 0.7464
# Epoch 30: val_accuracy did not improve from 0.73438
# 18/18 [==============================] - 6s 347ms/step - loss: 1.3114 - accuracy: 0.7464 - val_loss: 1.6048 - val_accuracy: 0.6953
# Epoch 31/100
# 18/18 [==============================] - ETA: 0s - loss: 1.2688 - accuracy: 0.7669
# Epoch 31: val_accuracy did not improve from 0.73438
# 18/18 [==============================] - 6s 337ms/step - loss: 1.2688 - accuracy: 0.7669 - val_loss: 1.4878 - val_accuracy: 0.7109
# Epoch 32/100
# 18/18 [==============================] - ETA: 0s - loss: 1.2202 - accuracy: 0.7767
# Epoch 32: val_accuracy did not improve from 0.73438
# 18/18 [==============================] - 7s 402ms/step - loss: 1.2202 - accuracy: 0.7767 - val_loss: 1.5102 - val_accuracy: 0.7031
# Epoch 33/100
# 18/18 [==============================] - ETA: 0s - loss: 1.1467 - accuracy: 0.8114
# Epoch 33: val_accuracy improved from 0.73438 to 0.74219, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 7s 409ms/step - loss: 1.1467 - accuracy: 0.8114 - val_loss: 1.4070 - val_accuracy: 0.7422
# Epoch 34/100
# 18/18 [==============================] - ETA: 0s - loss: 1.1686 - accuracy: 0.7918
# Epoch 34: val_accuracy did not improve from 0.74219
# 18/18 [==============================] - 6s 337ms/step - loss: 1.1686 - accuracy: 0.7918 - val_loss: 1.4298 - val_accuracy: 0.7109
# Epoch 35/100
# 18/18 [==============================] - ETA: 0s - loss: 1.0744 - accuracy: 0.8274
# Epoch 35: val_accuracy did not improve from 0.74219
# 18/18 [==============================] - 7s 409ms/step - loss: 1.0744 - accuracy: 0.8274 - val_loss: 1.3131 - val_accuracy: 0.7422
# Epoch 36/100
# 18/18 [==============================] - ETA: 0s - loss: 1.0262 - accuracy: 0.8550
# Epoch 36: val_accuracy improved from 0.74219 to 0.75000, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 6s 336ms/step - loss: 1.0262 - accuracy: 0.8550 - val_loss: 1.3340 - val_accuracy: 0.7500
# Epoch 37/100
# 18/18 [==============================] - ETA: 0s - loss: 1.0092 - accuracy: 0.8550
# Epoch 37: val_accuracy did not improve from 0.75000
# 18/18 [==============================] - 7s 401ms/step - loss: 1.0092 - accuracy: 0.8550 - val_loss: 1.3611 - val_accuracy: 0.7266
# Epoch 38/100
# 18/18 [==============================] - ETA: 0s - loss: 0.9861 - accuracy: 0.8674
# Epoch 38: val_accuracy did not improve from 0.75000
# 18/18 [==============================] - 6s 330ms/step - loss: 0.9861 - accuracy: 0.8674 - val_loss: 1.3627 - val_accuracy: 0.7500
# Epoch 39/100
# 18/18 [==============================] - ETA: 0s - loss: 0.9917 - accuracy: 0.8603
# Epoch 39: val_accuracy did not improve from 0.75000
# 18/18 [==============================] - 6s 330ms/step - loss: 0.9917 - accuracy: 0.8603 - val_loss: 1.3562 - val_accuracy: 0.7266
# Epoch 40/100
# 18/18 [==============================] - ETA: 0s - loss: 0.9179 - accuracy: 0.8772
# Epoch 40: val_accuracy improved from 0.75000 to 0.75781, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 6s 349ms/step - loss: 0.9179 - accuracy: 0.8772 - val_loss: 1.4139 - val_accuracy: 0.7578
# Epoch 41/100
# 18/18 [==============================] - ETA: 0s - loss: 0.9298 - accuracy: 0.8781
# Epoch 41: val_accuracy did not improve from 0.75781
# 18/18 [==============================] - 6s 340ms/step - loss: 0.9298 - accuracy: 0.8781 - val_loss: 1.4267 - val_accuracy: 0.7031
# Epoch 42/100
# 18/18 [==============================] - ETA: 0s - loss: 0.9082 - accuracy: 0.8852
# Epoch 42: val_accuracy improved from 0.75781 to 0.76562, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 7s 406ms/step - loss: 0.9082 - accuracy: 0.8852 - val_loss: 1.2713 - val_accuracy: 0.7656
# Epoch 43/100
# 18/18 [==============================] - ETA: 0s - loss: 0.8667 - accuracy: 0.8843
# Epoch 43: val_accuracy did not improve from 0.76562
# 18/18 [==============================] - 6s 337ms/step - loss: 0.8667 - accuracy: 0.8843 - val_loss: 1.2266 - val_accuracy: 0.7266
# Epoch 44/100
# 18/18 [==============================] - ETA: 0s - loss: 0.8546 - accuracy: 0.8986
# Epoch 44: val_accuracy did not improve from 0.76562
# 18/18 [==============================] - 7s 410ms/step - loss: 0.8546 - accuracy: 0.8986 - val_loss: 1.4198 - val_accuracy: 0.7266
# Epoch 45/100
# 18/18 [==============================] - ETA: 0s - loss: 0.8637 - accuracy: 0.8870
# Epoch 45: val_accuracy did not improve from 0.76562
# 18/18 [==============================] - 6s 336ms/step - loss: 0.8637 - accuracy: 0.8870 - val_loss: 1.3979 - val_accuracy: 0.6953
# Epoch 46/100
# 18/18 [==============================] - ETA: 0s - loss: 0.8940 - accuracy: 0.8781
# Epoch 46: val_accuracy did not improve from 0.76562
# 18/18 [==============================] - 6s 328ms/step - loss: 0.8940 - accuracy: 0.8781 - val_loss: 1.3836 - val_accuracy: 0.7188
# Epoch 47/100
# 18/18 [==============================] - ETA: 0s - loss: 0.8424 - accuracy: 0.9048
# Epoch 47: val_accuracy did not improve from 0.76562
# 18/18 [==============================] - 7s 399ms/step - loss: 0.8424 - accuracy: 0.9048 - val_loss: 1.3006 - val_accuracy: 0.6953
# Epoch 48/100
# 18/18 [==============================] - ETA: 0s - loss: 0.8084 - accuracy: 0.9119
# Epoch 48: val_accuracy did not improve from 0.76562
# 18/18 [==============================] - 6s 329ms/step - loss: 0.8084 - accuracy: 0.9119 - val_loss: 1.3514 - val_accuracy: 0.7344
# Epoch 49/100
# 18/18 [==============================] - ETA: 0s - loss: 0.7623 - accuracy: 0.9128
# Epoch 49: val_accuracy did not improve from 0.76562
# 18/18 [==============================] - 7s 382ms/step - loss: 0.7623 - accuracy: 0.9128 - val_loss: 1.3138 - val_accuracy: 0.7500
# Epoch 50/100
# 18/18 [==============================] - ETA: 0s - loss: 0.7598 - accuracy: 0.9039
# Epoch 50: val_accuracy did not improve from 0.76562
# 18/18 [==============================] - 8s 463ms/step - loss: 0.7598 - accuracy: 0.9039 - val_loss: 1.3400 - val_accuracy: 0.7422
# Epoch 51/100
# 18/18 [==============================] - ETA: 0s - loss: 0.7547 - accuracy: 0.9253
# Epoch 51: val_accuracy did not improve from 0.76562
# 18/18 [==============================] - 7s 392ms/step - loss: 0.7547 - accuracy: 0.9253 - val_loss: 1.2419 - val_accuracy: 0.7656
# Epoch 52/100
# 18/18 [==============================] - ETA: 0s - loss: 0.7698 - accuracy: 0.9101
# Epoch 52: val_accuracy did not improve from 0.76562
# 18/18 [==============================] - 7s 364ms/step - loss: 0.7698 - accuracy: 0.9101 - val_loss: 1.3713 - val_accuracy: 0.7109
# Epoch 53/100
# 18/18 [==============================] - ETA: 0s - loss: 0.7486 - accuracy: 0.9066
# Epoch 53: val_accuracy did not improve from 0.76562
# 18/18 [==============================] - 8s 426ms/step - loss: 0.7486 - accuracy: 0.9066 - val_loss: 1.2351 - val_accuracy: 0.7578
# Epoch 54/100
# 18/18 [==============================] - ETA: 0s - loss: 0.7589 - accuracy: 0.9128
# Epoch 54: val_accuracy improved from 0.76562 to 0.77344, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 7s 420ms/step - loss: 0.7589 - accuracy: 0.9128 - val_loss: 1.2044 - val_accuracy: 0.7734
# Epoch 55/100
# 18/18 [==============================] - ETA: 0s - loss: 0.7846 - accuracy: 0.8995
# Epoch 55: val_accuracy improved from 0.77344 to 0.78125, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 6s 345ms/step - loss: 0.7846 - accuracy: 0.8995 - val_loss: 1.2420 - val_accuracy: 0.7812
# Epoch 56/100
# 18/18 [==============================] - ETA: 0s - loss: 0.7406 - accuracy: 0.9146
# Epoch 56: val_accuracy did not improve from 0.78125
# 18/18 [==============================] - 7s 414ms/step - loss: 0.7406 - accuracy: 0.9146 - val_loss: 1.2685 - val_accuracy: 0.7812
# Epoch 57/100
# 18/18 [==============================] - ETA: 0s - loss: 0.7254 - accuracy: 0.9217
# Epoch 57: val_accuracy did not improve from 0.78125
# 18/18 [==============================] - 6s 341ms/step - loss: 0.7254 - accuracy: 0.9217 - val_loss: 1.3716 - val_accuracy: 0.7266
# Epoch 58/100
# 18/18 [==============================] - ETA: 0s - loss: 0.7104 - accuracy: 0.9270
# Epoch 58: val_accuracy did not improve from 0.78125
# 18/18 [==============================] - 7s 414ms/step - loss: 0.7104 - accuracy: 0.9270 - val_loss: 1.2065 - val_accuracy: 0.7812
# Epoch 59/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6960 - accuracy: 0.9324
# Epoch 59: val_accuracy did not improve from 0.78125
# 18/18 [==============================] - 7s 401ms/step - loss: 0.6960 - accuracy: 0.9324 - val_loss: 1.2421 - val_accuracy: 0.7734
# Epoch 60/100
# 18/18 [==============================] - ETA: 0s - loss: 0.7176 - accuracy: 0.9253
# Epoch 60: val_accuracy did not improve from 0.78125
# 18/18 [==============================] - 6s 332ms/step - loss: 0.7176 - accuracy: 0.9253 - val_loss: 1.1649 - val_accuracy: 0.7734
# Epoch 61/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6682 - accuracy: 0.9413
# Epoch 61: val_accuracy did not improve from 0.78125
# 18/18 [==============================] - 8s 428ms/step - loss: 0.6682 - accuracy: 0.9413 - val_loss: 1.1626 - val_accuracy: 0.7578
# Epoch 62/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6680 - accuracy: 0.9422
# Epoch 62: val_accuracy did not improve from 0.78125
# 18/18 [==============================] - 6s 332ms/step - loss: 0.6680 - accuracy: 0.9422 - val_loss: 1.2305 - val_accuracy: 0.7578
# Epoch 63/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6117 - accuracy: 0.9511
# Epoch 63: val_accuracy did not improve from 0.78125
# 18/18 [==============================] - 7s 354ms/step - loss: 0.6117 - accuracy: 0.9511 - val_loss: 1.1816 - val_accuracy: 0.7578
# Epoch 64/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6248 - accuracy: 0.9351
# Epoch 64: val_accuracy improved from 0.78125 to 0.80469, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 8s 430ms/step - loss: 0.6248 - accuracy: 0.9351 - val_loss: 1.0578 - val_accuracy: 0.8047
# Epoch 65/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6380 - accuracy: 0.9377
# Epoch 65: val_accuracy did not improve from 0.80469
# 18/18 [==============================] - 7s 415ms/step - loss: 0.6380 - accuracy: 0.9377 - val_loss: 1.3814 - val_accuracy: 0.7266
# Epoch 66/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6638 - accuracy: 0.9297
# Epoch 66: val_accuracy did not improve from 0.80469
# 18/18 [==============================] - 6s 343ms/step - loss: 0.6638 - accuracy: 0.9297 - val_loss: 1.1577 - val_accuracy: 0.7734
# Epoch 67/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6363 - accuracy: 0.9475
# Epoch 67: val_accuracy did not improve from 0.80469
# 18/18 [==============================] - 7s 405ms/step - loss: 0.6363 - accuracy: 0.9475 - val_loss: 1.0959 - val_accuracy: 0.7812
# Epoch 68/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6138 - accuracy: 0.9484
# Epoch 68: val_accuracy did not improve from 0.80469
# 18/18 [==============================] - 6s 336ms/step - loss: 0.6138 - accuracy: 0.9484 - val_loss: 1.0825 - val_accuracy: 0.7969
# Epoch 69/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6162 - accuracy: 0.9448
# Epoch 69: val_accuracy did not improve from 0.80469
# 18/18 [==============================] - 7s 352ms/step - loss: 0.6162 - accuracy: 0.9448 - val_loss: 1.0740 - val_accuracy: 0.7969
# Epoch 70/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6146 - accuracy: 0.9413
# Epoch 70: val_accuracy did not improve from 0.80469
# 18/18 [==============================] - 7s 413ms/step - loss: 0.6146 - accuracy: 0.9413 - val_loss: 1.1380 - val_accuracy: 0.7891
# Epoch 71/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6048 - accuracy: 0.9484
# Epoch 71: val_accuracy did not improve from 0.80469
# 18/18 [==============================] - 6s 333ms/step - loss: 0.6048 - accuracy: 0.9484 - val_loss: 1.1359 - val_accuracy: 0.7812
# Epoch 72/100
# 18/18 [==============================] - ETA: 0s - loss: 0.5915 - accuracy: 0.9484
# Epoch 72: val_accuracy did not improve from 0.80469
# 18/18 [==============================] - 7s 404ms/step - loss: 0.5915 - accuracy: 0.9484 - val_loss: 1.2295 - val_accuracy: 0.7344
# Epoch 73/100
# 18/18 [==============================] - ETA: 0s - loss: 0.5967 - accuracy: 0.9511
# Epoch 73: val_accuracy did not improve from 0.80469
# 18/18 [==============================] - 8s 419ms/step - loss: 0.5967 - accuracy: 0.9511 - val_loss: 1.1123 - val_accuracy: 0.7812
# Epoch 74/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6174 - accuracy: 0.9395
# Epoch 74: val_accuracy did not improve from 0.80469
# 18/18 [==============================] - 6s 329ms/step - loss: 0.6174 - accuracy: 0.9395 - val_loss: 1.3117 - val_accuracy: 0.7188
# Epoch 75/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6167 - accuracy: 0.9466
# Epoch 75: val_accuracy did not improve from 0.80469
# 18/18 [==============================] - 7s 410ms/step - loss: 0.6167 - accuracy: 0.9466 - val_loss: 1.1803 - val_accuracy: 0.7734
# Epoch 76/100
# 18/18 [==============================] - ETA: 0s - loss: 0.5819 - accuracy: 0.9537
# Epoch 76: val_accuracy did not improve from 0.80469
# 18/18 [==============================] - 7s 413ms/step - loss: 0.5819 - accuracy: 0.9537 - val_loss: 1.4220 - val_accuracy: 0.7188
# Epoch 77/100
# 18/18 [==============================] - ETA: 0s - loss: 0.5602 - accuracy: 0.9555
# Epoch 77: val_accuracy did not improve from 0.80469
# 18/18 [==============================] - 6s 327ms/step - loss: 0.5602 - accuracy: 0.9555 - val_loss: 1.1931 - val_accuracy: 0.7734
# Epoch 78/100
# 18/18 [==============================] - ETA: 0s - loss: 0.5768 - accuracy: 0.9457
# Epoch 78: val_accuracy did not improve from 0.80469
# 18/18 [==============================] - 7s 401ms/step - loss: 0.5768 - accuracy: 0.9457 - val_loss: 1.0429 - val_accuracy: 0.7969
# Epoch 79/100
# 18/18 [==============================] - ETA: 0s - loss: 0.5350 - accuracy: 0.9573
# Epoch 79: val_accuracy did not improve from 0.80469
# 18/18 [==============================] - 7s 413ms/step - loss: 0.5350 - accuracy: 0.9573 - val_loss: 1.0607 - val_accuracy: 0.7812
# Epoch 80/100
# 18/18 [==============================] - ETA: 0s - loss: 0.5180 - accuracy: 0.9635
# Epoch 80: val_accuracy improved from 0.80469 to 0.82812, saving model to /content/model_checkpoint.h5
# 18/18 [==============================] - 6s 345ms/step - loss: 0.5180 - accuracy: 0.9635 - val_loss: 0.9490 - val_accuracy: 0.8281
# Epoch 81/100
# 18/18 [==============================] - ETA: 0s - loss: 0.4840 - accuracy: 0.9706
# Epoch 81: val_accuracy did not improve from 0.82812
# 18/18 [==============================] - 7s 350ms/step - loss: 0.4840 - accuracy: 0.9706 - val_loss: 0.9834 - val_accuracy: 0.7891
# Epoch 82/100
# 18/18 [==============================] - ETA: 0s - loss: 0.5249 - accuracy: 0.9520
# Epoch 82: val_accuracy did not improve from 0.82812
# 18/18 [==============================] - 7s 416ms/step - loss: 0.5249 - accuracy: 0.9520 - val_loss: 1.0381 - val_accuracy: 0.8203
# Epoch 83/100
# 18/18 [==============================] - ETA: 0s - loss: 0.5201 - accuracy: 0.9591
# Epoch 83: val_accuracy did not improve from 0.82812
# 18/18 [==============================] - 6s 343ms/step - loss: 0.5201 - accuracy: 0.9591 - val_loss: 0.9687 - val_accuracy: 0.7969
# Epoch 84/100
# 18/18 [==============================] - ETA: 0s - loss: 0.5228 - accuracy: 0.9546
# Epoch 84: val_accuracy did not improve from 0.82812
# 18/18 [==============================] - 6s 342ms/step - loss: 0.5228 - accuracy: 0.9546 - val_loss: 1.0057 - val_accuracy: 0.7891
# Epoch 85/100
# 18/18 [==============================] - ETA: 0s - loss: 0.5495 - accuracy: 0.9484
# Epoch 85: val_accuracy did not improve from 0.82812
# 18/18 [==============================] - 7s 408ms/step - loss: 0.5495 - accuracy: 0.9484 - val_loss: 1.1149 - val_accuracy: 0.7500
# Epoch 86/100
# 18/18 [==============================] - ETA: 0s - loss: 0.5621 - accuracy: 0.9502
# Epoch 86: val_accuracy did not improve from 0.82812
# 18/18 [==============================] - 7s 375ms/step - loss: 0.5621 - accuracy: 0.9502 - val_loss: 1.0583 - val_accuracy: 0.7812
# Epoch 87/100
# 18/18 [==============================] - ETA: 0s - loss: 0.5443 - accuracy: 0.9617
# Epoch 87: val_accuracy did not improve from 0.82812
# 18/18 [==============================] - 6s 333ms/step - loss: 0.5443 - accuracy: 0.9617 - val_loss: 1.0029 - val_accuracy: 0.8203
# Epoch 88/100
# 18/18 [==============================] - ETA: 0s - loss: 0.5381 - accuracy: 0.9555
# Epoch 88: val_accuracy did not improve from 0.82812
# 18/18 [==============================] - 7s 416ms/step - loss: 0.5381 - accuracy: 0.9555 - val_loss: 1.0492 - val_accuracy: 0.7734
# Epoch 89/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6021 - accuracy: 0.9431
# Epoch 89: val_accuracy did not improve from 0.82812
# 18/18 [==============================] - 7s 406ms/step - loss: 0.6021 - accuracy: 0.9431 - val_loss: 1.3258 - val_accuracy: 0.7422
# Epoch 90/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6061 - accuracy: 0.9440
# Epoch 90: val_accuracy did not improve from 0.82812
# 18/18 [==============================] - 6s 345ms/step - loss: 0.6061 - accuracy: 0.9440 - val_loss: 1.5541 - val_accuracy: 0.7500
# Epoch 91/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6577 - accuracy: 0.9395
# Epoch 91: val_accuracy did not improve from 0.82812
# 18/18 [==============================] - 7s 415ms/step - loss: 0.6577 - accuracy: 0.9395 - val_loss: 1.1950 - val_accuracy: 0.7891
# Epoch 92/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6411 - accuracy: 0.9520
# Epoch 92: val_accuracy did not improve from 0.82812
# 18/18 [==============================] - 6s 333ms/step - loss: 0.6411 - accuracy: 0.9520 - val_loss: 1.2393 - val_accuracy: 0.8125
# Epoch 93/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6461 - accuracy: 0.9466
# Epoch 93: val_accuracy did not improve from 0.82812
# 18/18 [==============================] - 7s 355ms/step - loss: 0.6461 - accuracy: 0.9466 - val_loss: 1.1194 - val_accuracy: 0.7578
# Epoch 94/100
# 18/18 [==============================] - ETA: 0s - loss: 0.6374 - accuracy: 0.9466
# Epoch 94: val_accuracy did not improve from 0.82812
# 18/18 [==============================] - 7s 389ms/step - loss: 0.6374 - accuracy: 0.9466 - val_loss: 1.1136 - val_accuracy: 0.8125
# Epoch 95/100
# 18/18 [==============================] - ETA: 0s - loss: 0.5772 - accuracy: 0.9689
# Epoch 95: val_accuracy did not improve from 0.82812
# 18/18 [==============================] - 7s 351ms/step - loss: 0.5772 - accuracy: 0.9689 - val_loss: 1.1015 - val_accuracy: 0.7812
# Epoch 95: early stopping

# %%
metrics = history.history
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(history.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')

# %% [markdown]
# ## Model Evaluation

# %%
model.evaluate(test_spectrogram_ds, return_dict=True)
# Out:
# 3/3 [==============================] - 1s 184ms/step - loss: 1.0707 - accuracy: 0.8092
# {'loss': 1.070662021636963, 'accuracy': 0.8092105388641357}

# %%
y_pred = model.predict(test_spectrogram_ds)
# Out:
# 3/3 [==============================] - 0s 58ms/step

# %%
y_pred = tf.argmax(y_pred, axis=1)

# %%
y_true = tf.concat(list(test_spectrogram_ds.map(lambda s,lab: lab)), axis=0)

# %%
class_mapping = {
    '1': ' oragh',
    '13': 'sandogh sahami',
    '19': 'sandogh ghabele moamele',
    '17': 'sandogh mokhtalet',
    '15': 'sandogh daramad sabet',
    '11': 'felezat',
    '9': 'moshtagaht',
    '8': 'naft',
    '7': 'tala',
    '5': 'bank',
    '4': 'sekke',
    '3': 'arz',
}

class_names = [class_mapping[label] for label in label_names]

confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=class_names,
            yticklabels=class_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()
